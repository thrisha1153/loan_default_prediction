# %%
import pandas as pd

# %%
df=pd.read_csv("/content/cleaned_data.csv")
df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available       Unknown     type1
# 1  24891  2019         cf               Male       Unknown     type2
# 2  24892  2019         cf               Male       Unknown     type1
# 3  24893  2019         cf               Male       Unknown     type1
# 4  24894  2019         cf              Joint       Unknown     type1
#
#    loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0             1                l1        nopc                  nob/c  ...
# 1             1                l1        nopc                    b/c  ...
# 2             1                l1        nopc                  nob/c  ...
# 3             4                l1        nopc                  nob/c  ...
# 4             1                l1        nopc                  nob/c  ...
#
#    Credit_Score  co-applicant_credit_type    age  submission_of_application  \
# 0           758                       CIB  25-34                    to_inst
# 1           552                       EXP  55-64                    to_inst
# 2           834                       CIB  35-44                    to_inst
# 3           587                       CIB  45-54                   not_inst
# 4           602                       EXP  25-34                   not_inst
#
#          LTV Region Security_Type  Status      dtir1 loan_limit_encoded
# 0  98.728814  south        direct       1  45.000000                  0
# 1  72.746457  North        direct       1  37.732932                  0
# 2  80.019685  south        direct       0  46.000000                  0
# 3  69.376900  North        direct       0  42.000000                  0
# 4  91.886544  North        direct       0  39.000000                  0
#
# [5 rows x 34 columns]

# %%
df.shape
# Out:
# (148670, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 148670 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              148670 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148670 non-null  int64
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  float64
#  11  rate_of_interest           148670 non-null  float64
#  12  Interest_rate_spread       148670 non-null  float64
#  13  term                       148670 non-null  int64
#  14  Neg_ammortization          148670 non-null  object
#  15  interest_only              148670 non-null  object
#  16  lump_sum_payment           148670 non-null  object
#  17  property_value             148670 non-null  float64
#  18  construction_type          148670 non-null  object
#  19  occupancy_type             148670 non-null  object
#  20  Secured_by                 148670 non-null  object
#  21  total_units                148670 non-null  object
#  22  income                     148670 non-null  float64
#  23  credit_type                148670 non-null  object
#  24  Credit_Score               148670 non-null  int64
#  25  co-applicant_credit_type   148670 non-null  object
#  26  age                        148670 non-null  object
#  27  submission_of_application  148670 non-null  object
#  28  LTV                        148670 non-null  float64
#  29  Region                     148670 non-null  object
#  30  Security_Type              148670 non-null  object
#  31  Status                     148670 non-null  int64
#  32  dtir1                      148670 non-null  float64
#  33  loan_limit_encoded         148670 non-null  int64
# dtypes: float64(7), int64(7), object(20)
# memory usage: 38.6+ MB

# %%
df.describe()
# Out:
#                   ID      year   loan_purpose   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  148670.000000  1.486700e+05     148670.000000
# mean    99224.500000    2019.0       2.879364  3.311177e+05          4.045476
# std     42917.476598       0.0       1.145947  1.839093e+05          0.487764
# min     24890.000000    2019.0       0.000000  1.650000e+04          0.000000
# 25%     62057.250000    2019.0       2.000000  1.965000e+05          3.750000
# 50%     99224.500000    2019.0       3.000000  2.965000e+05          4.045476
# 75%    136391.750000    2019.0       4.000000  4.365000e+05          4.250000
# max    173559.000000    2019.0       4.000000  3.576500e+06          8.000000
#
#        Interest_rate_spread      term  property_value         income  \
# count         148670.000000  148670.0    1.486700e+05  148670.000000
# mean               0.441962     360.0    4.979956e+05    6957.664298
# std                0.445520       0.0    3.411697e+05    6293.492132
# min               -3.638000     360.0    8.000000e+03       0.000000
# 25%                0.181500     360.0    2.880000e+05    3840.000000
# 50%                0.441962     360.0    4.580000e+05    6000.000000
# 75%                0.621600     360.0    5.980000e+05    8280.000000
# max                3.357000     360.0    1.650800e+07  578580.000000
#
#         Credit_Score            LTV         Status          dtir1  \
# count  148670.000000  148670.000000  148670.000000  148670.000000
# mean      699.789103      72.746457       0.246445      37.732932
# std       115.875857      37.883839       0.430942       9.652119
# min       500.000000       0.967478       0.000000       5.000000
# 25%       599.000000      63.297872       0.000000      33.000000
# 50%       699.000000      73.026316       0.000000      37.732932
# 75%       800.000000      84.722222       0.000000      44.000000
# max       900.000000    7831.250000       1.000000      61.000000
#
#        loan_limit_encoded
# count       148670.000000
# mean             0.067579
# std              0.251023
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for col in df.columns:
  if df[col].dtype=='object':
    df[col]=le.fit_transform(df[col])

# %%
df=df.drop("loan_limit_encoded",axis=1)

# %%
df.corr()["Status"].sort_values(ascending=False)
# Out:
# Status                       1.000000
# co-applicant_credit_type     0.144239
# submission_of_application    0.122410
# credit_type                  0.112760
# dtir1                        0.061290
# loan_limit                   0.053783
# loan_type                    0.052301
# Gender                       0.051794
# age                          0.048807
# Region                       0.047142
# Credit_Worthiness            0.034875
# LTV                          0.031465
# Secured_by                   0.026055
# total_units                  0.023800
# Credit_Score                 0.004004
# rate_of_interest             0.001952
# ID                           0.001703
# Interest_rate_spread         0.001201
# open_credit                 -0.009979
# interest_only               -0.013881
# occupancy_type              -0.018588
# Security_Type               -0.026055
# construction_type           -0.026055
# loan_purpose                -0.027895
# loan_amount                 -0.036825
# property_value              -0.039006
# income                      -0.063712
# business_or_commercial      -0.092550
# Neg_ammortization           -0.155835
# lump_sum_payment            -0.187752
# year                              NaN
# approv_in_adv                     NaN
# term                              NaN
# Name: Status, dtype: float64

# %%
pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.10/dist-packages (0.2.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.1.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost->lazypredict) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.17.0)

# %%
pip install lux
# Out:
# Requirement already satisfied: lux in /usr/local/lib/python3.10/dist-packages (0.5.1)
# Requirement already satisfied: lux-api in /usr/local/lib/python3.10/dist-packages (from lux) (0.5.1)
# Requirement already satisfied: lux-widget in /usr/local/lib/python3.10/dist-packages (from lux) (0.1.11)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (1.13.1)
# Requirement already satisfied: altair>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (5.5.0)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (1.6.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (3.8.0)
# Requirement already satisfied: autopep8>=1.5 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (2.3.1)
# Requirement already satisfied: iso3166 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (2.1.1)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (5.9.5)
# Requirement already satisfied: sh in /usr/local/lib/python3.10/dist-packages (from lux-api->lux) (2.1.0)
# Requirement already satisfied: notebook>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from lux-widget->lux) (6.5.5)
# Requirement already satisfied: ipywidgets>=7.5.0 in /usr/local/lib/python3.10/dist-packages (from lux-widget->lux) (7.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair>=4.0.0->lux-api->lux) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair>=4.0.0->lux-api->lux) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from altair>=4.0.0->lux-api->lux) (1.18.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from altair>=4.0.0->lux-api->lux) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from altair>=4.0.0->lux-api->lux) (4.12.2)
# Requirement already satisfied: pycodestyle>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from autopep8>=1.5->lux-api->lux) (2.12.1)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from autopep8>=1.5->lux-api->lux) (2.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.0->lux-widget->lux) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.0->lux-widget->lux) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.0->lux-widget->lux) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->lux-api->lux) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->lux-api->lux) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->lux-api->lux) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->lux-api->lux) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->lux-api->lux) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->lux-api->lux) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->lux-api->lux) (2.8.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (6.3.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (6.1.12)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.0.0->lux-widget->lux) (1.1.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->lux-api->lux) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->lux-api->lux) (3.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lux-api->lux) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->lux-api->lux) (2024.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.0.0->lux-widget->lux) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.0.0->lux-widget->lux) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.0.0->lux-widget->lux) (2.21.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->lux-api->lux) (1.17.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook>=4.0.0->lux-widget->lux) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.0.0->lux-widget->lux) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.8.4)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget->lux) (1.24.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.13)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget->lux) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.0.0->lux-widget->lux) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget->lux) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget->lux) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget->lux) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget->lux) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget->lux) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget->lux) (1.2.2)

# %%
X=df.drop("Status",axis=1)
y=df["Status"]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)

# %%
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=rf.predict(X_test)

# %%
print(accuracy_score(pred,y_test))
# Out:
# 0.9998520212551288

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(pred,y_test)
# Out:
# array([[55891,    11],
#        [    0, 18433]])
